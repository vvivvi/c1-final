# %%
import sys
import os.path
import json
import numpy as np
import pandas as pd 
import sklearn
import scipy.sparse 
from itertools import product
import gc
import re
from catboost import CatBoostRegressor, Pool
from utils import load_feature_set, clipped_rmse, HoldOut
import pickle

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab import drive
  drive.mount('/content/gdrive') 
  if not os.path.isfile('SETTINGS.json'):
       # hard coded data directory in drive is used if SETTINGS.json not present 
       config={}
       config['DATA_DIR'] = '/content/gdrive/My Drive/kaggle-c1'
       with open('SETTINGS.json', 'w') as outfile:
         json.dump(config, outfile)

with open('SETTINGS.json') as config_file:
    config = json.load(config_file)

DATA_DIR = config['DATA_DIR']

print('Using DATA_DIR ', DATA_DIR)

DATA_FOLDER = DATA_DIR
# Out:
# Using DATA_DIR  c:\repos\c1-final-test\datadir

# %% [markdown]
# # Feature selection
#
# The purpose of the code in this notebook is to run sequential forward selection wrapper method for feature selection
# from the pre-generated five feature subsets (basic, text, within, allfeat, basicv2). The features
# are selected to maximise the performance
# in a validation experiment in terms of the clipped RMSE metric
# of a trained CatBoost regressor (with fixed parameters).
# The code writes full feature selection paths to a disk file, containing the  feature subsets
# with number of the selected features covering the whole 1-25.
#
#
#
# ## Choosing the validation setup
#
# Choosing a good validation strategy is problematic. There may not be too much that can be done, because the validation data necessarily has different distribution as the actual testing data. This is because the temporal nature of the prediction problem. The distributions slowly drift during cause of time. Therefore, it would be good to have the validation period temporally close to the test period. On the other hand, data analysis shows strong seasonal (=yearly) effects. For example, if we eould choose last training month (Oct 2015) as the validation set, predicting October sales based on previous months simply is a very different problem to predicting December sales, as sales figures seem to peak strongly in December and may otherwise have special characteristics.
#
# Here we have chosen another alternative: predicting the sales of the last training December  month (2014) based on the previous data. In return of better matching the yearly cycle, we sacrifice quite much in temporal closeness of validation and test periods, as well as in smaller amount of validation data.
#
# We are fully aware of the shortcomings of the validation scheme. Without a good cross-validation schreme in place, the
# selection algorithm (and similarly the hyperparameter search in the notebook 5) is likely to severely overfit to the data.
# Rigorous cross-validation would be difficult to set up and would necessarily be a compromise between bad options,
# for the similar reasons whole validation is challenging: balancing between the amount of data used and the temporal proximity, strong yearly cycles.
#
# Therefore, we shamelessly also advocate validation on the public leaderboard in this case, if we have only a small number of choices to evaluate. This depends on a data leak from th the test set via the leaderboard, but in a competition anything goes if only rules are not violated.

# %% [markdown]
# ## Feature selection code

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import json

# start from existing results if they exist
with open(os.path.join(DATA_FOLDER,'search_path_sfs.pickle'), 'rb') as fp:    
            search_path_sfs = pickle.load(fp)
        
target_featcount = 25        

for id in ['allfeat','basic','basicv2','text','within']:
    if id in list(search_path_sfs.keys()):
        print('skipping already searched feature set {}'.format(id))
        continue;
        
    print('selecting features for feature set {}'.format(id))
    X_train, y_train, X_val, y_val = load_feature_set(id, data_folder=DATA_FOLDER, datasets='train_and_val')

    X_paramsearch =  pd.concat([X_train, X_val],ignore_index=True)
    y_paramsearch = pd.concat([y_train, y_val],ignore_index=True)
    train_indices = np.arange(X_train.shape[0])
    val_indices = np.arange(X_val.shape[0]) + X_train.shape[0]

    # 'item_price' generation is wrongly performed -> drop that column, if present
    
    to_drop_cols=[col for col in X_paramsearch.columns.values if re.search('item_price',col) ]
    
    X_paramsearch=X_paramsearch.drop(to_drop_cols,axis=1)
    ncol=X_paramsearch.shape[1]
    
    regparams={'learning_rate': 0.5, 'iterations': 30, 'depth': 12, 'l2_leaf_reg': 0.3, 'task_type': 'GPU', 'metric_period':30}
    model = CatBoostRegressor(**regparams)
    cv = HoldOut(train_indices=train_indices, test_indices=val_indices)

    sfs1 = SFS(model, 
           k_features=min(target_featcount,ncol-1), 
           forward=True, 
           floating=False, 
           scoring='neg_mean_squared_error',
           verbose=3,
           cv=cv)

    sfs1 = sfs1.fit(X_paramsearch, y_paramsearch)
    print('Feature selection path for feature subset {}:'.format(id))
    print(sfs1.subsets_)

    search_path_sfs[id]=sfs1.subsets_

    with open(os.path.join(DATA_FOLDER,'search_path_sfs.pickle'), 'wb') as fp:    
        pickle.dump (search_path_sfs, fp)

    del model
    del X_train
    del y_train
    del X_val
    del y_val
    del X_paramsearch
    del y_paramsearch
    gc.collect()
# Out:
# skipping already searched feature set allfeat
# skipping already searched feature set basic
# skipping already searched feature set basicv2
# skipping already searched feature set text
# skipping already searched feature set within

# %% [markdown]
# Just for a check, print out the found feature selection paths

# %%
with open(os.path.join(DATA_FOLDER,'search_path_sfs.pickle'), 'rb') as fp:    
            search_path_sfs = pickle.load(fp)

search_path_sfs
# Out:
# {'allfeat': {1: {'feature_idx': (38,),
#    'cv_scores': array([-2.30684221]),
#    'avg_score': -2.306842212802926,
#    'feature_names': ('target_lag_2',)},
#   2: {'feature_idx': (38, 39),
#    'cv_scores': array([-2.19293825]),
#    'avg_score': -2.1929382460204048,
#    'feature_names': ('target_lag_2', 'item_category_id')},
#   3: {'feature_idx': (38, 39, 46),
#    'cv_scores': array([-2.11309329]),
#    'avg_score': -2.113093291795761,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_lag_5')},
#   4: {'feature_idx': (38, 39, 46, 47),
#    'cv_scores': array([-2.02533126]),
#    'avg_score': -2.025331256778903,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12')},
#   5: {'feature_idx': (37, 38, 39, 46, 47),
#    'cv_scores': array([-1.98108481]),
#    'avg_score': -1.981084814344693,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12')},
#   6: {'feature_idx': (37, 38, 39, 44, 46, 47),
#    'cv_scores': array([-1.92542547]),
#    'avg_score': -1.925425471894777,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12')},
#   7: {'feature_idx': (37, 38, 39, 44, 45, 46, 47),
#    'cv_scores': array([-1.87894227]),
#    'avg_score': -1.8789422659379906,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12')},
#   8: {'feature_idx': (37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.85620536]),
#    'avg_score': -1.8562053553308724,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   9: {'feature_idx': (34, 37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.84430363]),
#    'avg_score': -1.8443036274222757,
#    'feature_names': ('target_lag_3',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   10: {'feature_idx': (10, 34, 37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.82119751]),
#    'avg_score': -1.8211975125729485,
#    'feature_names': ('target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   11: {'feature_idx': (10, 13, 34, 37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.82413519]),
#    'avg_score': -1.8241351885565686,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_lag_3',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   12: {'feature_idx': (10, 13, 19, 34, 37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.82340414]),
#    'avg_score': -1.8234041390828204,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_lag_3',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   13: {'feature_idx': (10, 13, 19, 34, 36, 37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.81032248]),
#    'avg_score': -1.810322484113152,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_lag_3',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   14: {'feature_idx': (10, 13, 19, 31, 34, 36, 37, 38, 39, 44, 45, 46, 47, 60),
#    'cv_scores': array([-1.81913596]),
#    'avg_score': -1.8191359636867195,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_lag_3',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   15: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     34,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     60),
#    'cv_scores': array([-1.80441361]),
#    'avg_score': -1.804413610342214,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_lag_3',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   16: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     60),
#    'cv_scores': array([-1.80526089]),
#    'avg_score': -1.8052608934243424,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12')},
#   17: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     60,
#     62),
#    'cv_scores': array([-1.80739265]),
#    'avg_score': -1.8073926538737082,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2')},
#   18: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     60,
#     62),
#    'cv_scores': array([-1.81412832]),
#    'avg_score': -1.8141283223242366,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2')},
#   19: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     60,
#     62,
#     63),
#    'cv_scores': array([-1.79804323]),
#    'avg_score': -1.7980432265797444,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2')},
#   20: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     48,
#     60,
#     62,
#     63),
#    'cv_scores': array([-1.82493693]),
#    'avg_score': -1.8249369299969787,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2')},
#   21: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     48,
#     60,
#     62,
#     63,
#     75),
#    'cv_scores': array([-1.80446371]),
#    'avg_score': -1.8044637080212365,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'time_of_year')},
#   22: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     48,
#     60,
#     62,
#     63,
#     67,
#     75),
#    'cv_scores': array([-1.7916825]),
#    'avg_score': -1.7916825008893198,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_lag_3',
#     'time_of_year')},
#   23: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     33,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     48,
#     60,
#     62,
#     63,
#     67,
#     75),
#    'cv_scores': array([-1.77262156]),
#    'avg_score': -1.7726215591764622,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_lag_3',
#     'time_of_year')},
#   24: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     33,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     48,
#     58,
#     60,
#     62,
#     63,
#     67,
#     75),
#    'cv_scores': array([-1.80214371]),
#    'avg_score': -1.8021437067684993,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_lag_3',
#     'time_of_year')},
#   25: {'feature_idx': (10,
#     13,
#     19,
#     23,
#     31,
#     32,
#     33,
#     34,
#     35,
#     36,
#     37,
#     38,
#     39,
#     44,
#     45,
#     46,
#     47,
#     48,
#     54,
#     58,
#     60,
#     62,
#     63,
#     67,
#     75),
#    'cv_scores': array([-1.80172368]),
#    'avg_score': -1.8017236821058464,
#    'feature_names': ('target_item_lag_3',
#     'target_item_lag_6',
#     'target_category_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_category_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_lag_5',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_bigram_256',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'target_category_frequent_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_lag_3',
#     'time_of_year')}},
#  'basic': {1: {'feature_idx': (4,),
#    'cv_scores': array([-2.30714067]),
#    'avg_score': -2.3071406713348543,
#    'feature_names': ('target_lag_2',)},
#   2: {'feature_idx': (4, 8),
#    'cv_scores': array([-2.19316415]),
#    'avg_score': -2.1931641505919184,
#    'feature_names': ('target_lag_2', 'item_category_id')},
#   3: {'feature_idx': (4, 8, 22),
#    'cv_scores': array([-2.13069255]),
#    'avg_score': -2.1306925500168488,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_item_lag_12')},
#   4: {'feature_idx': (4, 8, 16, 22),
#    'cv_scores': array([-2.04773933]),
#    'avg_score': -2.0477393267233284,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_shop_lag_12',
#     'target_item_lag_12')},
#   5: {'feature_idx': (4, 8, 14, 16, 22),
#    'cv_scores': array([-1.93429272]),
#    'avg_score': -1.9342927218157289,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_item_lag_12')},
#   6: {'feature_idx': (1, 4, 8, 14, 16, 22),
#    'cv_scores': array([-1.9210053]),
#    'avg_score': -1.9210053007954944,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_item_lag_12')},
#   7: {'feature_idx': (1, 4, 8, 14, 16, 19, 22),
#    'cv_scores': array([-1.86096955]),
#    'avg_score': -1.86096955450811,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12')},
#   8: {'feature_idx': (1, 4, 8, 14, 16, 19, 22, 33),
#    'cv_scores': array([-1.83173014]),
#    'avg_score': -1.8317301392710035,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'time_of_year')},
#   9: {'feature_idx': (1, 4, 8, 14, 16, 19, 22, 27, 33),
#    'cv_scores': array([-1.83687562]),
#    'avg_score': -1.8368756210311812,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   10: {'feature_idx': (1, 4, 8, 10, 14, 16, 19, 22, 27, 33),
#    'cv_scores': array([-1.82981045]),
#    'avg_score': -1.8298104467696084,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_2',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   11: {'feature_idx': (1, 4, 8, 10, 14, 16, 17, 19, 22, 27, 33),
#    'cv_scores': array([-1.82193953]),
#    'avg_score': -1.8219395310143236,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_2',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   12: {'feature_idx': (1, 3, 4, 8, 10, 14, 16, 17, 19, 22, 27, 33),
#    'cv_scores': array([-1.83850655]),
#    'avg_score': -1.8385065522416717,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_2',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   13: {'feature_idx': (1, 3, 4, 8, 10, 14, 15, 16, 17, 19, 22, 27, 33),
#    'cv_scores': array([-1.83556618]),
#    'avg_score': -1.835566178220748,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_2',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   14: {'feature_idx': (1, 3, 4, 8, 10, 14, 15, 16, 17, 19, 21, 22, 27, 33),
#    'cv_scores': array([-1.84232573]),
#    'avg_score': -1.8423257317766581,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_2',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   15: {'feature_idx': (1, 3, 4, 8, 10, 12, 14, 15, 16, 17, 19, 21, 22, 27, 33),
#    'cv_scores': array([-1.84163965]),
#    'avg_score': -1.8416396500975905,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   16: {'feature_idx': (1,
#     3,
#     4,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     19,
#     21,
#     22,
#     27,
#     33),
#    'cv_scores': array([-1.81845171]),
#    'avg_score': -1.8184517126602067,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'time_of_year')},
#   17: {'feature_idx': (1,
#     3,
#     4,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     19,
#     21,
#     22,
#     27,
#     30,
#     33),
#    'cv_scores': array([-1.81192465]),
#    'avg_score': -1.8119246547132806,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'time_of_year')},
#   18: {'feature_idx': (1,
#     3,
#     4,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     19,
#     21,
#     22,
#     27,
#     30,
#     33),
#    'cv_scores': array([-1.80615187]),
#    'avg_score': -1.8061518691473408,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'time_of_year')},
#   19: {'feature_idx': (1,
#     3,
#     4,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     19,
#     21,
#     22,
#     24,
#     27,
#     30,
#     33),
#    'cv_scores': array([-1.82878407]),
#    'avg_score': -1.8287840662637236,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'time_of_year')},
#   20: {'feature_idx': (1,
#     3,
#     4,
#     5,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     19,
#     21,
#     22,
#     24,
#     27,
#     30,
#     33),
#    'cv_scores': array([-1.82266072]),
#    'avg_score': -1.8226607197887092,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'time_of_year')},
#   21: {'feature_idx': (1,
#     3,
#     4,
#     5,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     19,
#     21,
#     22,
#     23,
#     24,
#     27,
#     30,
#     33),
#    'cv_scores': array([-1.82670878]),
#    'avg_score': -1.826708783095112,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_3',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'time_of_year')},
#   22: {'feature_idx': (1,
#     3,
#     4,
#     5,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     27,
#     30,
#     33),
#    'cv_scores': array([-1.84399053]),
#    'avg_score': -1.843990533088231,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_3',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'time_of_year')},
#   23: {'feature_idx': (1,
#     3,
#     4,
#     5,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     27,
#     30,
#     31,
#     33),
#    'cv_scores': array([-1.84296074]),
#    'avg_score': -1.8429607414787088,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_3',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'target_lag_3',
#     'target_item_lag_6',
#     'time_of_year')},
#   24: {'feature_idx': (1,
#     3,
#     4,
#     5,
#     7,
#     8,
#     9,
#     10,
#     12,
#     14,
#     15,
#     16,
#     17,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     27,
#     29,
#     30,
#     31,
#     33),
#    'cv_scores': array([-1.82190288]),
#    'avg_score': -1.8219028826448704,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_3',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'is_internet_store',
#     'target_lag_3',
#     'target_item_lag_6',
#     'time_of_year')},
#   25: {'feature_idx': (1,
#     3,
#     4,
#     5,
#     7,
#     8,
#     9,
#     10,
#     11,
#     12,
#     14,
#     15,
#     16,
#     17,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     27,
#     29,
#     30,
#     31,
#     33),
#    'cv_scores': array([-1.83074888]),
#    'avg_score': -1.8307488783651829,
#    'feature_names': ('target_item_lag_4',
#     'target_shop_lag_6',
#     'target_lag_2',
#     'target_shop_lag_5',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_lag_2',
#     'target_category_lag_6',
#     'target_lag_4',
#     'target_item_lag_2',
#     'target_lag_6',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_item_lag_12',
#     'target_shop_lag_3',
#     'target_shop_lag_2',
#     'item_name_category_tfidf_bigram_256',
#     'is_internet_store',
#     'target_lag_3',
#     'target_item_lag_6',
#     'time_of_year')}},
#  'basicv2': {1: {'feature_idx': (7,),
#    'cv_scores': array([-2.30880431]),
#    'avg_score': -2.3088043070161306,
#    'feature_names': ('target_lag_2',)},
#   2: {'feature_idx': (7, 53),
#    'cv_scores': array([-2.21207465]),
#    'avg_score': -2.2120746485680853,
#    'feature_names': ('target_lag_2', 'target_lag_3')},
#   3: {'feature_idx': (7, 11, 53),
#    'cv_scores': array([-2.15889153]),
#    'avg_score': -2.158891530098225,
#    'feature_names': ('target_lag_2', 'item_category_id', 'target_lag_3')},
#   4: {'feature_idx': (7, 11, 17, 53),
#    'cv_scores': array([-2.08829123]),
#    'avg_score': -2.0882912254673602,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_lag_3')},
#   5: {'feature_idx': (7, 11, 17, 42, 53),
#    'cv_scores': array([-2.05694213]),
#    'avg_score': -2.0569421313739253,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_lag_3')},
#   6: {'feature_idx': (7, 11, 17, 42, 46, 53),
#    'cv_scores': array([-1.96829594]),
#    'avg_score': -1.9682959392348431,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   7: {'feature_idx': (7, 11, 17, 33, 42, 46, 53),
#    'cv_scores': array([-1.93383508]),
#    'avg_score': -1.9338350781726326,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_shop_lag_12',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   8: {'feature_idx': (7, 11, 17, 33, 38, 42, 46, 53),
#    'cv_scores': array([-1.89010022]),
#    'avg_score': -1.8901002216533236,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   9: {'feature_idx': (7, 11, 17, 26, 33, 38, 42, 46, 53),
#    'cv_scores': array([-1.83224913]),
#    'avg_score': -1.8322491331854422,
#    'feature_names': ('target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   10: {'feature_idx': (3, 7, 11, 17, 26, 33, 38, 42, 46, 53),
#    'cv_scores': array([-1.81645052]),
#    'avg_score': -1.8164505158197033,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   11: {'feature_idx': (3, 7, 11, 17, 24, 26, 33, 38, 42, 46, 53),
#    'cv_scores': array([-1.81149114]),
#    'avg_score': -1.8114911379715968,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   12: {'feature_idx': (3, 7, 10, 11, 17, 24, 26, 33, 38, 42, 46, 53),
#    'cv_scores': array([-1.81139251]),
#    'avg_score': -1.8113925103103625,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   13: {'feature_idx': (3, 7, 10, 11, 17, 24, 26, 33, 38, 41, 42, 46, 53),
#    'cv_scores': array([-1.81231215]),
#    'avg_score': -1.8123121465852519,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'target_category_lag_4',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   14: {'feature_idx': (3, 7, 10, 11, 17, 24, 26, 33, 34, 38, 41, 42, 46, 53),
#    'cv_scores': array([-1.78269757]),
#    'avg_score': -1.7826975688446378,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   15: {'feature_idx': (3,
#     7,
#     10,
#     11,
#     17,
#     24,
#     26,
#     33,
#     34,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53),
#    'cv_scores': array([-1.79033778]),
#    'avg_score': -1.7903377794119997,
#    'feature_names': ('target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   16: {'feature_idx': (2,
#     3,
#     7,
#     10,
#     11,
#     17,
#     24,
#     26,
#     33,
#     34,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53),
#    'cv_scores': array([-1.79347741]),
#    'avg_score': -1.793477411500487,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3')},
#   17: {'feature_idx': (2,
#     3,
#     7,
#     10,
#     11,
#     17,
#     24,
#     26,
#     33,
#     34,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     56),
#    'cv_scores': array([-1.75498989]),
#    'avg_score': -1.754989889101768,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   18: {'feature_idx': (2,
#     3,
#     7,
#     10,
#     11,
#     17,
#     24,
#     26,
#     33,
#     34,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56),
#    'cv_scores': array([-1.75781382]),
#    'avg_score': -1.7578138223741393,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   19: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     17,
#     24,
#     26,
#     33,
#     34,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56),
#    'cv_scores': array([-1.77990833]),
#    'avg_score': -1.7799083303001633,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   20: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     17,
#     24,
#     26,
#     33,
#     34,
#     36,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56),
#    'cv_scores': array([-1.75807736]),
#    'avg_score': -1.7580773551171494,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   21: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     17,
#     19,
#     24,
#     26,
#     33,
#     34,
#     36,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56),
#    'cv_scores': array([-1.78153028]),
#    'avg_score': -1.781530277595179,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   22: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     17,
#     19,
#     24,
#     26,
#     33,
#     34,
#     36,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56,
#     57),
#    'cv_scores': array([-1.77071957]),
#    'avg_score': -1.7707195651960792,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3',
#     'time_of_year')},
#   23: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     17,
#     19,
#     20,
#     24,
#     26,
#     33,
#     34,
#     36,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56,
#     57),
#    'cv_scores': array([-1.78922411]),
#    'avg_score': -1.7892241072937296,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_lag_6',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3',
#     'time_of_year')},
#   24: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     12,
#     17,
#     19,
#     20,
#     24,
#     26,
#     33,
#     34,
#     36,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56,
#     57),
#    'cv_scores': array([-1.77455224]),
#    'avg_score': -1.7745522415756199,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_lag_6',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3',
#     'time_of_year')},
#   25: {'feature_idx': (2,
#     3,
#     4,
#     7,
#     10,
#     11,
#     12,
#     17,
#     19,
#     20,
#     23,
#     24,
#     26,
#     33,
#     34,
#     36,
#     38,
#     40,
#     41,
#     42,
#     46,
#     53,
#     55,
#     56,
#     57),
#    'cv_scores': array([-1.81910919]),
#    'avg_score': -1.8191091880344217,
#    'feature_names': ('target_category_within_shop_lag_4',
#     'target_item_lag_4',
#     'target_shop_lag_4',
#     'target_lag_2',
#     'target_lag_12',
#     'item_category_id',
#     'target_category_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'item_id',
#     'target_item_lag_2',
#     'target_shop_lag_12',
#     'item_name_cyrillic_fraction',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_lag_4',
#     'target_item_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_item_lag_12',
#     'target_item_lag_3',
#     'target_lag_3',
#     'target_item_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_3',
#     'time_of_year')}},
#  'text': {1: {'feature_idx': (12,),
#    'cv_scores': array([-2.68610122]),
#    'avg_score': -2.6861012165542157,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_2',)},
#   2: {'feature_idx': (6, 12),
#    'cv_scores': array([-2.55559592]),
#    'avg_score': -2.5555959159433055,
#    'feature_names': ('item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_2')},
#   3: {'feature_idx': (6, 11, 12),
#    'cv_scores': array([-2.49277031]),
#    'avg_score': -2.4927703125411056,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2')},
#   4: {'feature_idx': (6, 11, 12, 36),
#    'cv_scores': array([-2.48463424]),
#    'avg_score': -2.4846342409596236,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'item_name_category_tfidf_unigram_256')},
#   5: {'feature_idx': (6, 11, 12, 22, 36),
#    'cv_scores': array([-2.45940496]),
#    'avg_score': -2.459404961951443,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_frequent_256_lag_5',
#     'item_name_category_tfidf_unigram_256')},
#   6: {'feature_idx': (6, 11, 12, 22, 27, 36),
#    'cv_scores': array([-2.43741243]),
#    'avg_score': -2.437412430100362,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_frequent_256_lag_5',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_unigram_256')},
#   7: {'feature_idx': (6, 11, 12, 22, 27, 36, 43),
#    'cv_scores': array([-2.41758305]),
#    'avg_score': -2.4175830524318087,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_frequent_256_lag_5',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_unigram_256',
#     'item_name_category_frequent_256')},
#   8: {'feature_idx': (6, 11, 12, 22, 27, 36, 37, 43),
#    'cv_scores': array([-2.39294806]),
#    'avg_score': -2.392948057303676,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_frequent_256_lag_5',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_unigram_256',
#     'item_name_category_tfidf_bigram_256',
#     'item_name_category_frequent_256')},
#   9: {'feature_idx': (6, 11, 12, 15, 22, 27, 36, 37, 43),
#    'cv_scores': array([-2.36980926]),
#    'avg_score': -2.3698092592234175,
#    'feature_names': ('item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_12',
#     'target_category_frequent_256_lag_5',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_unigram_256',
#     'item_name_category_tfidf_bigram_256',
#     'item_name_category_frequent_256')},
#   10: {'feature_idx': (5, 6, 11, 12, 15, 22, 27, 36, 37, 43),
#    'cv_scores': array([-2.36538417]),
#    'avg_score': -2.365384169182542,
#    'feature_names': ('date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_12',
#     'target_category_frequent_256_lag_5',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_unigram_256',
#     'item_name_category_tfidf_bigram_256',
#     'item_name_category_frequent_256')},
#   11: {'feature_idx': (4, 5, 6, 11, 12, 15, 22, 27, 36, 37, 43),
#    'cv_scores': array([-2.36084142]),
#    'avg_score': -2.3608414234095254,
#    'feature_names': ('target_category_tfidf_unigram_256_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_unigram_256_within_shop_lag_12',
#     'target_category_frequent_256_lag_5',
#     'item_name_cyrillic_fraction',
#     'item_name_category_tfidf_unigram_256',
#     'item_name_category_tfidf_bigram_256',
#     'item_name_category_frequent_256')},
#   12: {'feature_idx': (4, 5, 6, 11, 12, 15, 22, 27, 30, 36, 37, 43),
# ...
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_3')},
#   12: {'feature_idx': (0, 1, 3, 4, 10, 14, 17, 19, 20, 22, 23, 25),
#    'cv_scores': array([-2.41679903]),
#    'avg_score': -2.4167990294169774,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_3')},
#   13: {'feature_idx': (0, 1, 3, 4, 10, 14, 17, 19, 20, 22, 23, 24, 25),
#    'cv_scores': array([-2.40261398]),
#    'avg_score': -2.4026139785984024,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3')},
#   14: {'feature_idx': (0, 1, 3, 4, 10, 14, 17, 19, 20, 22, 23, 24, 25, 27),
#    'cv_scores': array([-2.41399426]),
#    'avg_score': -2.413994264512421,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   15: {'feature_idx': (0, 1, 3, 4, 8, 10, 14, 17, 19, 20, 22, 23, 24, 25, 27),
#    'cv_scores': array([-2.43336253]),
#    'avg_score': -2.433362525135032,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   16: {'feature_idx': (0,
#     1,
#     3,
#     4,
#     8,
#     10,
#     12,
#     14,
#     17,
#     19,
#     20,
#     22,
#     23,
#     24,
#     25,
#     27),
#    'cv_scores': array([-2.42769395]),
#    'avg_score': -2.4276939490981166,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   17: {'feature_idx': (0,
#     1,
#     3,
#     4,
#     8,
#     10,
#     12,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     27),
#    'cv_scores': array([-2.42982574]),
#    'avg_score': -2.4298257434435393,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   18: {'feature_idx': (0,
#     1,
#     3,
#     4,
#     8,
#     10,
#     12,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.41455581]),
#    'avg_score': -2.414555808567511,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   19: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     8,
#     10,
#     12,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.42690886]),
#    'avg_score': -2.4269088607367975,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   20: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     6,
#     8,
#     10,
#     12,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.43635014]),
#    'avg_score': -2.436350135588786,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   21: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     6,
#     8,
#     10,
#     12,
#     13,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.41845568]),
#    'avg_score': -2.41845568310709,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'item_id',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   22: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     6,
#     8,
#     9,
#     10,
#     12,
#     13,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.4390862]),
#    'avg_score': -2.4390861972754374,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'item_id',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   23: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     6,
#     7,
#     8,
#     9,
#     10,
#     12,
#     13,
#     14,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.43524284]),
#    'avg_score': -2.435242837931111,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'item_id',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   24: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     6,
#     7,
#     8,
#     9,
#     10,
#     12,
#     13,
#     14,
#     16,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.42828816]),
#    'avg_score': -2.428288163829344,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'item_id',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_tfidf_bigram_256_within_shop_lag_6',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')},
#   25: {'feature_idx': (0,
#     1,
#     2,
#     3,
#     4,
#     6,
#     7,
#     8,
#     9,
#     10,
#     12,
#     13,
#     14,
#     15,
#     16,
#     17,
#     19,
#     20,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27),
#    'cv_scores': array([-2.40257387]),
#    'avg_score': -2.402573873879694,
#    'feature_names': ('target_category_tfidf_bigram_256_within_shop_lag_12',
#     'target_category_within_shop_lag_4',
#     'target_category_within_shop_lag_2',
#     'date_block_num',
#     'item_category_id',
#     'target_category_frequent_256_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_6',
#     'target_category_tfidf_unigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_2',
#     'target_category_tfidf_bigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_6',
#     'item_id',
#     'target_category_frequent_256_within_shop_lag_4',
#     'target_category_within_shop_lag_12',
#     'target_category_tfidf_bigram_256_within_shop_lag_6',
#     'target_category_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_5',
#     'target_category_tfidf_unigram_256_within_shop_lag_5',
#     'target_category_within_shop_lag_5',
#     'target_category_frequent_256_within_shop_lag_12',
#     'shop_id',
#     'target_category_frequent_256_within_shop_lag_3',
#     'target_category_tfidf_bigram_256_within_shop_lag_3',
#     'target_category_tfidf_unigram_256_within_shop_lag_4',
#     'target_category_tfidf_unigram_256_within_shop_lag_3')}}}

# %% [markdown]
# The results reveal interesting things about feature importance. Some of these match well with prior expectations. For instance, whenever available the feature with most predictive power seems to be the value of the sales in the last preceding training month, i.e. 'target_lag_2'.
#
# It is nice to notice that both the features based on textual categories, and the shop-wise features get selected when all the features are available. Generating them was not wasted work.
